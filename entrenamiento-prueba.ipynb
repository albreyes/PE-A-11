# %%
import pandas as pd

dataPath='C:/Users/areyes/Dropbox/ineel/cemie redes/PE-A-11/datasets/bajioCentralGRT-central/'
data=pd.read_csv(dataPath+'LINEASBASE-arb-redCausal.csv')

# %%
data.head()
# Out:
#    NAME  AB  ST EHG  AP CHCH  BC CIM PCI DES  ... COND CECN SEP  CE BRE ACC  \
# 0     1  S5  S5  S5  S5   S5  S5  S4  S5  S5  ...   S5   S5  S5  S5  S4  S5
# 1     2  S5  S5  S5  S5   S5  S5  S4  S5  S5  ...   S5   S5  S5  S5  S4  S5
# 2     3  S5  S5  S5  S5   S5  S5  S4  S5  S5  ...   S5   S5  S5  S5  S4  S5
# 3     4  S5  S5  S5  S5   S5  S5  S4  S5  S5  ...   S5   S5  S5  S5  S4  S5
# 4     5  S5  S5  S5  S5   S5  S5  S4  S5  S5  ...   S5   S5  S5  S5  S4  S5
#
#   COM NOMS      T     LT
# 0  S1   S1  0.934  93020
# 1  S1   S1  0.934  93020
# 2  S1   S1  0.934  93020
# 3  S1   S1  0.934  93020
# 4  S1   S1  0.934  93020
#
# [5 rows x 28 columns]

# %%
X_all = data.drop(['NAME', 'T'], axis=1)

#Dejamos solo la clase T
y_all = data['T']

# %%
y_all.head()
# Out:
# 0    0.934
# 1    0.934
# 2    0.934
# 3    0.934
# 4    0.934
# Name: T, dtype: float64

# %%
from sklearn.model_selection import train_test_split

num_test = 0.20 # aquí se está especificando 20% para test
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=num_test)

# %%
X_train
# Out:
#      AB  ST EHG  AP CHCH  BC CIM PCI DES EST  ... CAMG COND CECN SEP  CE BRE  \
# 35   S5  S5  S5  S5   S5  S5  S4  S5  S5  S4  ...   S5   S5   S5  S5  S5  S4
# 90   S5  S5  S5  S5   S5  S5  S5  S5  S5  S5  ...   S5   S5   S5  S5  S5  S4
# 406  S5  S5  S5  S5   S5  S5  S4  S5  S5  S4  ...   S5   S5   S5  S5  S5  S4
# 516  S5  S5  S5  S5   S5  S5  S4  S5  S5  S5  ...   S5   S5   S5  S5  S5  S5
# 360  S3  S5  S5  S5   S5  S5  S4  S5  S5  S4  ...   S5   S5   S5  S5  S5  S4
# ..   ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ...  ...  ...  ...  ..  ..  ..
# 71   S5  S2  S5  S5   S5  S5  S5  S5  S5  S5  ...   S5   S5   S5  S5  S5  S4
# 513  S5  S5  S5  S5   S5  S5  S4  S5  S5  S4  ...   S5   S5   S5  S5  S5  S4
# 451  S5  S5  S5  S5   S5  S5  S4  S5  S5  S4  ...   S5   S5   S5  S5  S5  S4
# 304  S5  S5  S5  S5   S5  S5  S4  S5  S5  S4  ...   S5   S5   S5  S5  S5  S4
# 375  S3  S5  S5  S5   S5  S5  S4  S5  S5  S4  ...   S5   S5   S5  S5  S5  S4
#
#     ACC COM NOMS     LT
# ...

# %%
y_train
# Out:
# 35     0.934
# 90     0.984
# 406    0.936
# 516    0.958
# 360    0.896
#        ...
# 71     0.924
# 513    0.926
# 451    0.926
# 304    0.954
# 375    0.896
# Name: T, Length: 414, dtype: float64

# %%
X_train.to_csv(dataPath+'LINEASBASE-arb-redCausalEntrena80-5.csv')
X_test.to_csv(dataPath+'LINEASBASE-arb-redCausalPrueba80-5.csv')

# %%
data1=pd.read_csv(dataPath+'LINEASBASE-karla.csv')

# %%
data1.head()
# Out:
#    NAME  AB  ST  EHG  AP  CHCH  BC  CIM  PCI  DES  ...  COND  CECN  SEP  CE  \
# 0     1  10  10   10  10    10  10    8   10   10  ...    10    10   10  10
# 1     2  10  10   10  10    10  10    8   10   10  ...    10    10   10  10
# 2     3  10  10   10  10    10  10    8   10   10  ...    10    10   10  10
# 3     4  10  10   10  10    10  10    8   10   10  ...    10    10   10  10
# 4     5  10  10   10  10    10  10    8   10   10  ...    10    10   10  10
#
#    BRE  ACC  COM  NOMS      T     LT
# 0    8   10   10     4  0.934  93020
# 1    8   10   10     4  0.934  93020
# 2    8   10   10     4  0.934  93020
# 3    8   10   10     4  0.934  93020
# 4    8   10   10     4  0.934  93020
#
# [5 rows x 28 columns]

# %%
X_all = data1.drop(['NAME','T','LT'], axis=1)

#Borramos las columnas Survived 
y_all = data1['T']

# %%
X_all.head()
# Out:
#    AB  ST  EHG  AP  CHCH  BC  CIM  PCI  DES  EST  ...  CHH  CAMG  COND  CECN  \
# 0  10  10   10  10    10  10    8   10   10    8  ...    8    10    10    10
# 1  10  10   10  10    10  10    8   10   10    8  ...    8    10    10    10
# 2  10  10   10  10    10  10    8   10   10    8  ...    8    10    10    10
# 3  10  10   10  10    10  10    8   10   10    8  ...    8    10    10    10
# 4  10  10   10  10    10  10    8   10   10    8  ...    8    10    10    10
#
#    SEP  CE  BRE  ACC  COM  NOMS
# 0   10  10    8   10   10     4
# 1   10  10    8   10   10     4
# 2   10  10    8   10   10     4
# 3   10  10    8   10   10     4
# 4   10  10    8   10   10     4
#
# [5 rows x 25 columns]

# %%
y_all.head()
# Out:
# 0    0.934
# 1    0.934
# 2    0.934
# 3    0.934
# 4    0.934
# Name: T, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=20)

# %%
# Seleccionamos el tipo de clasificador, en este caso RandomForest. 
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10)
# entrenamiento
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-8c9b59a3a1ea> in <module>
#       3 clf = RandomForestClassifier(n_estimators=10)
#       4 # entrenamiento
# ----> 5 clf.fit(X_train, y_train)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     328         self.n_outputs_ = y.shape[1]
#     329
# --> 330         y, expanded_class_weight = self._validate_y_class_weight(y)
#     331
#     332         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\ensemble\_forest.py in _validate_y_class_weight(self, y)
#     556
#     557     def _validate_y_class_weight(self, y):
# --> 558         check_classification_targets(y)
#     559
#     560         y = np.copy(y)
#
# ...

# %%
y_all=y_all*100

# %%
y_all
# Out:
# 0      93.4
# 1      93.4
# 2      93.4
# 3      93.4
# 4      93.4
#        ...
# 513    92.6
# 514    92.6
# 515    92.6
# 516    95.8
# 517    95.8
# Name: T, Length: 518, dtype: float64

# %%
y_all=y_all.astype(int)

# %%
y_all
# Out:
# 0      93
# 1      93
# 2      93
# 3      93
# 4      93
#        ..
# 513    92
# 514    92
# 515    92
# 516    95
# 517    95
# Name: T, Length: 518, dtype: int32

# %%
# Seleccionamos el tipo de clasificador, en este caso RandomForest. 
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10)
# entrenamiento
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-8c9b59a3a1ea> in <module>
#       3 clf = RandomForestClassifier(n_estimators=10)
#       4 # entrenamiento
# ----> 5 clf.fit(X_train, y_train)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     328         self.n_outputs_ = y.shape[1]
#     329
# --> 330         y, expanded_class_weight = self._validate_y_class_weight(y)
#     331
#     332         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\ensemble\_forest.py in _validate_y_class_weight(self, y)
#     556
#     557     def _validate_y_class_weight(self, y):
# --> 558         check_classification_targets(y)
#     559
#     560         y = np.copy(y)
#
# ...
